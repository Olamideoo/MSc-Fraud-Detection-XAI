# %%
# Handle missing values
# Remove duplicates
# Encode categorical features
# Scale numerical features
# Train/Test Split
# Save processed dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data= pd.read_csv("C:\\Users\\Olami\\Downloads\\archive\\banking_transactions.csv")

data.head()
# Out:
#    transaction_id  transaction_amount  login_attempts  device_risk_score  \
# 0         1000001            17829.01               4               12.0
# 1         1000002            16401.83               1               34.3
# 2         1000003             9678.29               8               67.8
# 3         1000004            19013.38               5               17.8
# 4         1000005            13834.95               3               88.9
#
#    transfer_frequency  anomaly_score  account_age_days  transaction_time_hour  \
# 0                  13           0.37              2354                     22
# 1                  17           0.26              3181                     17
# 2                  39           0.15              1390                      3
# 3                  42           0.55              3716                     16
# 4                  63           0.24              4694                     16
#
# ...

# %%
data.info()
data.describe()
data.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   transaction_id                  10000 non-null  int64
#  1   transaction_amount              10000 non-null  float64
#  2   login_attempts                  10000 non-null  int64
#  3   device_risk_score               10000 non-null  float64
#  4   transfer_frequency              10000 non-null  int64
#  5   anomaly_score                   10000 non-null  float64
#  6   account_age_days                10000 non-null  int64
#  7   transaction_time_hour           10000 non-null  int64
#  8   failed_transactions_last_30d    10000 non-null  int64
#  9   avg_monthly_balance             10000 non-null  float64
#  10  daily_transaction_count         10000 non-null  int64
#  11  geo_distance_km                 10000 non-null  int64
# ...

# %%
#checking for duplicates
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data['fraud_flag'].value_counts()
# Out:
# fraud_flag
# False    8749
# True     1251
# Name: count, dtype: int64

# %%
data = data.drop('transaction_id', axis=1)

data['fraud_flag'] = data['fraud_flag'].astype(int)

data.to_csv('../data/cleaned_fraud_dataset.csv', index=False)

# %%
data.head()
# Out:
#    transaction_amount  login_attempts  device_risk_score  transfer_frequency  \
# 0            17829.01               4               12.0                  13
# 1            16401.83               1               34.3                  17
# 2             9678.29               8               67.8                  39
# 3            19013.38               5               17.8                  42
# 4            13834.95               3               88.9                  63
#
#    anomaly_score  account_age_days  transaction_time_hour  \
# 0           0.37              2354                     22
# 1           0.26              3181                     17
# 2           0.15              1390                      3
# 3           0.55              3716                     16
# 4           0.24              4694                     16
#
#    failed_transactions_last_30d  avg_monthly_balance  daily_transaction_count  \
# ...

# %%
print(data['payment_channel'].unique())
print(data['authentication_type'].unique())
# Out:
# <StringArray>
# ['POS Terminal', 'Web Banking', 'ATM', 'Mobile App']
# Length: 4, dtype: str
# <StringArray>
# ['OTP', 'Biometric', 'Two-Factor Authentication', 'Password Only']
# Length: 4, dtype: str

# %%
#Save cleaned dataset 
data.to_csv('../data/cleaned_fraud_dataset.csv', index=False)

print("Preprocessing completed successfully.")
# Out:
# Preprocessing completed successfully.

# %%
import os

print("Current directory:", os.getcwd())
print("Files:", os.listdir())
# Out:
# Current directory: c:\Users\Olami\OneDrive\Documents\DATASCIENCEPROJECT\MSc Fradulent_detection_XIA\Notebooks
# Files: ['01_Data_Understanding_EDA.ipynb', '02_Data_Preprocessing.ipynb', '03_Feature_engeneering.ipynb', '03_Model_Training.ipynb', '04_XAI_Analysis.ipynb']

# %%
import os

print(os.listdir(".."))
# Out:
# ['.git', '.gitignore', 'Data', 'Notebooks', 'README.md', 'requirements.txt']
